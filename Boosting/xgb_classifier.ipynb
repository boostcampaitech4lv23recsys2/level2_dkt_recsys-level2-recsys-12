# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

sys.path.append(r"../")
from data_loader import xgb_data_loader, xgb_PCA_data_loader
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score

from xgboost import XGBClassifier

from datetime import datetime

# %% [markdown]
# # Load Preprocessed data

# %%
IS_CUSTOM = True
USE_VALID = True
n_components = 0
DROPS = [
    "assessmentItemID",
    "testId",
    "Timestamp",
    "year",
    "day",
    "minute",
    "second",
    # 'userID',
    # 'KnowledgeTag',
    # 'userAnswerRate',
    # 'tagAnswerRate',
    # 'itemAnswerRate',
    # 'testAnswerRate',
    # 'timeConcentrationRate',
    # 'monthAnswerRate',
    # 'userSolvedLen',
    # 'testSolvedLen',
    # 'tagSolvedLen',
    # 'itemSolvedLen',
    # 'timeConcentrationCount',
    # 'monthSolvedCount',
    # 'userSolvedSum',
    # 'itemSolvedSum',
    # 'testSolvedSum',
    # 'tagSolvedSum',
    # 'timeConcentraionSum',
    # 'monthSolvedSum',
    # 'testSolvedVar',
    # 'userSolvedVar',
    # 'tagSolvedVar',
    # 'itemSolvedVar',
    # 'timeConcentrationVar',
    # 'monthSolvedVar',
    # 'timeConcentrationLevel',
    # 'month',
    # 'hour',
    # 'first3',
    # 'mid3',
    # 'last3',
    # 'user_correct_answer',
    # 'user_total_answer',
    # 'user_acc',
]
if n_components:
    x_train, x_valid, y_train, y_valid, test = xgb_PCA_data_loader(
        IS_CUSTOM=IS_CUSTOM, USE_VALID=USE_VALID, DROPS=DROPS, n_components=n_components
    )
else:
    x_train, x_valid, y_train, y_valid, test = xgb_data_loader(
        IS_CUSTOM=IS_CUSTOM, USE_VALID=USE_VALID, DROPS=DROPS
    )
# Out:
# Load data..........................................
# Split data..........................................
# Standard Scaling....................................
# Find PCA from data..........................................

# %% [markdown]
# # XGBClassifier

# %%
model = XGBClassifier(tree_method="gpu_hist", gpu_id=0)

if USE_VALID:
    model = XGBClassifier(tree_method="gpu_hist", gpu_id=0, early_stopping_rounds=100)

"""
final params {'alpha': 10, 'booster': 'gbtree', 'colsample_bylevel': 0.9,
 'colsample_bytree': 0.8, 'eta': 0.05, 'gamma': 3, 'lambda': 0, 'max_depth': 9,
  'n_estimators': 200, 'nthread': 4, 'objective': 'binary:logistic', 'random_state': 42, 'verbosity': 1}
"""
param_grid = {
    "booster": ["gbtree"],
    "colsample_bylevel": [0.9],
    "colsample_bytree": [0.8],
    "gamma": [3],
    "lambda": [0],
    "alpha": [10],
    "eta": [0.05],
    "max_depth": [9],
    # "min_child_weight": [3],
    # "nrounds":[100000],
    "n_estimators": [300],
    "nthread": [4],
    "objective": ["binary:logistic"],
    "random_state": [42],
    "verbosity": [1],
}
# cv = KFold(n_splits=6, random_state=42, shuffle=True)
cv = StratifiedKFold(n_splits=6, random_state=42, shuffle=True)

gcv = GridSearchCV(
    model,
    param_grid=param_grid,
    cv=cv,
    scoring="roc_auc",
    n_jobs=4,
    pre_dispatch=8,
    verbose=1,
)

# %%
if USE_VALID:
    gcv.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=True)
else:
    gcv.fit(x_train, y_train, verbose=True)

print("final params", gcv.best_params_)
print("best score", gcv.best_score_)
# Out:
# Fitting 6 folds for each of 1 candidates, totalling 6 fits
# [0]	validation_0-logloss:0.68510
# [1]	validation_0-logloss:0.67719
# [2]	validation_0-logloss:0.67049
# [3]	validation_0-logloss:0.66469
# [4]	validation_0-logloss:0.65968
# [5]	validation_0-logloss:0.65554
# [6]	validation_0-logloss:0.65214
# [7]	validation_0-logloss:0.65250
# [8]	validation_0-logloss:0.65228
# [9]	validation_0-logloss:0.64995
# [10]	validation_0-logloss:0.64845
# [11]	validation_0-logloss:0.64714
# [12]	validation_0-logloss:0.64599
# [13]	validation_0-logloss:0.64733
# [0]	validation_0-logloss:0.68504
# [0]	validation_0-logloss:0.68493
# [14]	validation_0-logloss:0.64645
# [1]	validation_0-logloss:0.67688
# [1]	validation_0-logloss:0.67678
# [15]	validation_0-logloss:0.64672
# [0]	validation_0-logloss:0.68512
# [2]	validation_0-logloss:0.67018
# [16]	validation_0-logloss:0.64620
# [1]	validation_0-logloss:0.67706
# [3]	validation_0-logloss:0.66397
# [2]	validation_0-logloss:0.67022
# [17]	validation_0-logloss:0.64597
# [2]	validation_0-logloss:0.67043
# [4]	validation_0-logloss:0.65932
# [3]	validation_0-logloss:0.66449
# [18]	validation_0-logloss:0.64616
# [3]	validation_0-logloss:0.66454
# [5]	validation_0-logloss:0.65502
# [4]	validation_0-logloss:0.65931
# [19]	validation_0-logloss:0.64664
# [4]	validation_0-logloss:0.65954
# [6]	validation_0-logloss:0.65187
# [5]	validation_0-logloss:0.65479
# [20]	validation_0-logloss:0.64702
# [5]	validation_0-logloss:0.65565
# [7]	validation_0-logloss:0.65239
# [6]	validation_0-logloss:0.65159
# [21]	validation_0-logloss:0.64794
# [6]	validation_0-logloss:0.65258
# [8]	validation_0-logloss:0.65249
# [7]	validation_0-logloss:0.65155
# [22]	validation_0-logloss:0.64984
# [7]	validation_0-logloss:0.65252
# [9]	validation_0-logloss:0.64972
# [8]	validation_0-logloss:0.65118
# [23]	validation_0-logloss:0.65182
# [8]	validation_0-logloss:0.65216
# [10]	validation_0-logloss:0.64792
# [9]	validation_0-logloss:0.64847
# [24]	validation_0-logloss:0.65310
# [9]	validation_0-logloss:0.64954
# [11]	validation_0-logloss:0.64683
# [10]	validation_0-logloss:0.64699
# [25]	validation_0-logloss:0.65325
# [10]	validation_0-logloss:0.64789
# [12]	validation_0-logloss:0.64583
# [11]	validation_0-logloss:0.64592
# [26]	validation_0-logloss:0.65493
# [11]	validation_0-logloss:0.64704
# [13]	validation_0-logloss:0.64691
# [12]	validation_0-logloss:0.64492
# [27]	validation_0-logloss:0.65569
# [12]	validation_0-logloss:0.64609
# [14]	validation_0-logloss:0.64614
# [13]	validation_0-logloss:0.64571
# [28]	validation_0-logloss:0.65638
# [13]	validation_0-logloss:0.64711
# [15]	validation_0-logloss:0.64622
# [14]	validation_0-logloss:0.64452
# [29]	validation_0-logloss:0.65693
# [14]	validation_0-logloss:0.64603
# [16]	validation_0-logloss:0.64591
# [15]	validation_0-logloss:0.64462
# [30]	validation_0-logloss:0.65790
# [15]	validation_0-logloss:0.64633
# [17]	validation_0-logloss:0.64541
# [16]	validation_0-logloss:0.64435
# [31]	validation_0-logloss:0.65895
# [16]	validation_0-logloss:0.64617
# [18]	validation_0-logloss:0.64550
# [17]	validation_0-logloss:0.64402
# [32]	validation_0-logloss:0.65998
# [17]	validation_0-logloss:0.64605
# [19]	validation_0-logloss:0.64581
# [18]	validation_0-logloss:0.64419
# [33]	validation_0-logloss:0.66102
# [18]	validation_0-logloss:0.64601
# [20]	validation_0-logloss:0.64631
# [19]	validation_0-logloss:0.64458
# [34]	validation_0-logloss:0.66180
# [19]	validation_0-logloss:0.64683
# [21]	validation_0-logloss:0.64725
# [20]	validation_0-logloss:0.64458
# [35]	validation_0-logloss:0.66314
# [20]	validation_0-logloss:0.64738
# [22]	validation_0-logloss:0.64899
# [21]	validation_0-logloss:0.64534
# [36]	validation_0-logloss:0.66431
# [21]	validation_0-logloss:0.64877
# [23]	validation_0-logloss:0.65066
# [22]	validation_0-logloss:0.64704
# [37]	validation_0-logloss:0.66545
# [22]	validation_0-logloss:0.65062
# [24]	validation_0-logloss:0.65175
# [23]	validation_0-logloss:0.64869
# [38]	validation_0-logloss:0.66648
# [23]	validation_0-logloss:0.65261
# [25]	validation_0-logloss:0.65252
# [24]	validation_0-logloss:0.64969
# [39]	validation_0-logloss:0.66770
# [24]	validation_0-logloss:0.65352
# [26]	validation_0-logloss:0.65400
# [25]	validation_0-logloss:0.65023
# [40]	validation_0-logloss:0.66855
# [25]	validation_0-logloss:0.65419
# [27]	validation_0-logloss:0.65486
# [26]	validation_0-logloss:0.65154
# [41]	validation_0-logloss:0.66986
# [26]	validation_0-logloss:0.65528
# [28]	validation_0-logloss:0.65510
# [27]	validation_0-logloss:0.65231
# [42]	validation_0-logloss:0.67087
# [27]	validation_0-logloss:0.65623
# [29]	validation_0-logloss:0.65618
# [28]	validation_0-logloss:0.65304
# [43]	validation_0-logloss:0.67160
# [28]	validation_0-logloss:0.65729
# [30]	validation_0-logloss:0.65679
# [29]	validation_0-logloss:0.65380
# [44]	validation_0-logloss:0.67265
# [29]	validation_0-logloss:0.65808
# [31]	validation_0-logloss:0.65768
# [30]	validation_0-logloss:0.65438
# [45]	validation_0-logloss:0.67331
# [30]	validation_0-logloss:0.65868
# [32]	validation_0-logloss:0.65890
# [31]	validation_0-logloss:0.65536
# [46]	validation_0-logloss:0.67392
# [31]	validation_0-logloss:0.65954
# [33]	validation_0-logloss:0.66008
# [32]	validation_0-logloss:0.65601
# [47]	validation_0-logloss:0.67443
# [32]	validation_0-logloss:0.66076
# [34]	validation_0-logloss:0.66098
# [33]	validation_0-logloss:0.65665
# [48]	validation_0-logloss:0.67553
# [33]	validation_0-logloss:0.66186
# [35]	validation_0-logloss:0.66212
# [34]	validation_0-logloss:0.65718
# [49]	validation_0-logloss:0.67662
# [34]	validation_0-logloss:0.66282
# [36]	validation_0-logloss:0.66289
# [35]	validation_0-logloss:0.65826
# [50]	validation_0-logloss:0.67786
# [35]	validation_0-logloss:0.66363
# [37]	validation_0-logloss:0.66402
# [36]	validation_0-logloss:0.65921
# [51]	validation_0-logloss:0.67879
# [36]	validation_0-logloss:0.66498
# [38]	validation_0-logloss:0.66516
# [37]	validation_0-logloss:0.66042
# [52]	validation_0-logloss:0.67964
# [37]	validation_0-logloss:0.66600
# [39]	validation_0-logloss:0.66636
# [38]	validation_0-logloss:0.66203
# [53]	validation_0-logloss:0.68055
# [38]	validation_0-logloss:0.66658
# [40]	validation_0-logloss:0.66758
# [39]	validation_0-logloss:0.66306
# [54]	validation_0-logloss:0.68157
# [39]	validation_0-logloss:0.66793
# [41]	validation_0-logloss:0.66874
# [40]	validation_0-logloss:0.66407
# [55]	validation_0-logloss:0.68218
# [40]	validation_0-logloss:0.66890
# [42]	validation_0-logloss:0.66926
# [41]	validation_0-logloss:0.66523
# [56]	validation_0-logloss:0.68271
# [41]	validation_0-logloss:0.67014
# [43]	validation_0-logloss:0.67031
# [42]	validation_0-logloss:0.66596
# [57]	validation_0-logloss:0.68336
# [42]	validation_0-logloss:0.67109
# [44]	validation_0-logloss:0.67164
# [43]	validation_0-logloss:0.66693
# [58]	validation_0-logloss:0.68376
# [43]	validation_0-logloss:0.67211
# [45]	validation_0-logloss:0.67234
# [44]	validation_0-logloss:0.66786
# [59]	validation_0-logloss:0.68450
# [44]	validation_0-logloss:0.67328
# [46]	validation_0-logloss:0.67305
# [45]	validation_0-logloss:0.66834
# [60]	validation_0-logloss:0.68538
# [45]	validation_0-logloss:0.67404
# [47]	validation_0-logloss:0.67377
# [46]	validation_0-logloss:0.66905
# [61]	validation_0-logloss:0.68671
# [46]	validation_0-logloss:0.67496
# [48]	validation_0-logloss:0.67472
# [47]	validation_0-logloss:0.66969
# [62]	validation_0-logloss:0.68766
# [47]	validation_0-logloss:0.67562
# [49]	validation_0-logloss:0.67594
# [48]	validation_0-logloss:0.67002
# [63]	validation_0-logloss:0.68852
# [48]	validation_0-logloss:0.67635
# [50]	validation_0-logloss:0.67683
# [49]	validation_0-logloss:0.67113
# [64]	validation_0-logloss:0.68923
# [49]	validation_0-logloss:0.67765
# [51]	validation_0-logloss:0.67791
# [50]	validation_0-logloss:0.67257
# [65]	validation_0-logloss:0.69012
# [50]	validation_0-logloss:0.67901
# [52]	validation_0-logloss:0.67865
# [51]	validation_0-logloss:0.67367
# [66]	validation_0-logloss:0.69100
# [51]	validation_0-logloss:0.67977
# [53]	validation_0-logloss:0.67909
# [52]	validation_0-logloss:0.67440
# [67]	validation_0-logloss:0.69204
# [52]	validation_0-logloss:0.68008
# [54]	validation_0-logloss:0.67988
# [53]	validation_0-logloss:0.67514
# [68]	validation_0-logloss:0.69251
# [53]	validation_0-logloss:0.68087
# [55]	validation_0-logloss:0.68095
# [54]	validation_0-logloss:0.67617
# [69]	validation_0-logloss:0.69324
# [54]	validation_0-logloss:0.68149
# [56]	validation_0-logloss:0.68142
# [55]	validation_0-logloss:0.67687
# [70]	validation_0-logloss:0.69378
# [57]	validation_0-logloss:0.68197
# [55]	validation_0-logloss:0.68215
# [56]	validation_0-logloss:0.67742
# [71]	validation_0-logloss:0.69390
# [56]	validation_0-logloss:0.68283
# [58]	validation_0-logloss:0.68246
# [57]	validation_0-logloss:0.67770
# [72]	validation_0-logloss:0.69464
# [57]	validation_0-logloss:0.68356
# [59]	validation_0-logloss:0.68322
# [58]	validation_0-logloss:0.67809
# [73]	validation_0-logloss:0.69553
# [58]	validation_0-logloss:0.68415
# [60]	validation_0-logloss:0.68383
# [59]	validation_0-logloss:0.67873
# [74]	validation_0-logloss:0.69617
# [59]	validation_0-logloss:0.68463
# [61]	validation_0-logloss:0.68463
# [60]	validation_0-logloss:0.67957
# [75]	validation_0-logloss:0.69671
# [60]	validation_0-logloss:0.68581
# [62]	validation_0-logloss:0.68579
# [61]	validation_0-logloss:0.68032
# [76]	validation_0-logloss:0.69714
# [61]	validation_0-logloss:0.68682
# [63]	validation_0-logloss:0.68662
# [62]	validation_0-logloss:0.68132
# [77]	validation_0-logloss:0.69746
# [62]	validation_0-logloss:0.68777
# [64]	validation_0-logloss:0.68728
# [63]	validation_0-logloss:0.68207
# [78]	validation_0-logloss:0.69802
# [63]	validation_0-logloss:0.68836
# [65]	validation_0-logloss:0.68828
# [64]	validation_0-logloss:0.68262
# [79]	validation_0-logloss:0.69851
# [64]	validation_0-logloss:0.68865
# [66]	validation_0-logloss:0.68898
# [65]	validation_0-logloss:0.68369
# [80]	validation_0-logloss:0.69876
# [65]	validation_0-logloss:0.68991
# [67]	validation_0-logloss:0.68987
# [66]	validation_0-logloss:0.68450
# [81]	validation_0-logloss:0.69947
# [66]	validation_0-logloss:0.69073
# [68]	validation_0-logloss:0.69049
# [67]	validation_0-logloss:0.68555
# [82]	validation_0-logloss:0.69958
# [67]	validation_0-logloss:0.69139
# [69]	validation_0-logloss:0.69098
# [68]	validation_0-logloss:0.68611
# [83]	validation_0-logloss:0.69999
# [68]	validation_0-logloss:0.69189
# [70]	validation_0-logloss:0.69157
# [69]	validation_0-logloss:0.68679
# [84]	validation_0-logloss:0.70018
# [69]	validation_0-logloss:0.69241
# [71]	validation_0-logloss:0.69166
# [70]	validation_0-logloss:0.68774
# [85]	validation_0-logloss:0.70060
# [70]	validation_0-logloss:0.69319
# [72]	validation_0-logloss:0.69209
# [71]	validation_0-logloss:0.68801
# [86]	validation_0-logloss:0.70090
# [71]	validation_0-logloss:0.69334
# [73]	validation_0-logloss:0.69278
# [72]	validation_0-logloss:0.68860
# [87]	validation_0-logloss:0.70145
# [74]	validation_0-logloss:0.69353
# [72]	validation_0-logloss:0.69416
# [73]	validation_0-logloss:0.68911
# [88]	validation_0-logloss:0.70164
# [75]	validation_0-logloss:0.69427
# [73]	validation_0-logloss:0.69490
# [89]	validation_0-logloss:0.70196
# [74]	validation_0-logloss:0.68982
# [76]	validation_0-logloss:0.69512
# [74]	validation_0-logloss:0.69538
# [75]	validation_0-logloss:0.69072
# [90]	validation_0-logloss:0.70245
# [75]	validation_0-logloss:0.69605
# [77]	validation_0-logloss:0.69553
# [91]	validation_0-logloss:0.70254
# [76]	validation_0-logloss:0.69144
# [76]	validation_0-logloss:0.69643
# [78]	validation_0-logloss:0.69607
# [92]	validation_0-logloss:0.70277
# [77]	validation_0-logloss:0.69189
# [79]	validation_0-logloss:0.69677
# [77]	validation_0-logloss:0.69714
# [93]	validation_0-logloss:0.70295
# [78]	validation_0-logloss:0.69235
# [80]	validation_0-logloss:0.69710
# [78]	validation_0-logloss:0.69763
# [94]	validation_0-logloss:0.70353
# [79]	validation_0-logloss:0.69258
# [81]	validation_0-logloss:0.69746
# [79]	validation_0-logloss:0.69810
# [95]	validation_0-logloss:0.70384
# [80]	validation_0-logloss:0.69293
# [82]	validation_0-logloss:0.69781
# [80]	validation_0-logloss:0.69825
# [96]	validation_0-logloss:0.70452
# [81]	validation_0-logloss:0.69337
# [83]	validation_0-logloss:0.69810
# [81]	validation_0-logloss:0.69873
# [97]	validation_0-logloss:0.70512
# [82]	validation_0-logloss:0.69414
# [84]	validation_0-logloss:0.69874
# [82]	validation_0-logloss:0.69919
# [98]	validation_0-logloss:0.70547
# [83]	validation_0-logloss:0.69445
# [85]	validation_0-logloss:0.69900
# [83]	validation_0-logloss:0.69950
# [99]	validation_0-logloss:0.70560
# [84]	validation_0-logloss:0.69478
# [86]	validation_0-logloss:0.69953
# [84]	validation_0-logloss:0.69999
# [100]	validation_0-logloss:0.70589
# [85]	validation_0-logloss:0.69499
# [87]	validation_0-logloss:0.69980
# [85]	validation_0-logloss:0.70005
# [101]	validation_0-logloss:0.70607
# [86]	validation_0-logloss:0.69527
# [88]	validation_0-logloss:0.70044
# [86]	validation_0-logloss:0.70060
# [102]	validation_0-logloss:0.70636
# [87]	validation_0-logloss:0.69579
# [89]	validation_0-logloss:0.70089
# [87]	validation_0-logloss:0.70123
# [103]	validation_0-logloss:0.70637
# [88]	validation_0-logloss:0.69637
# [90]	validation_0-logloss:0.70129
# [88]	validation_0-logloss:0.70175
# [104]	validation_0-logloss:0.70649
# [89]	validation_0-logloss:0.69675
# [91]	validation_0-logloss:0.70154
# [89]	validation_0-logloss:0.70217
# [105]	validation_0-logloss:0.70668
# [90]	validation_0-logloss:0.69715
# [92]	validation_0-logloss:0.70181
# [90]	validation_0-logloss:0.70278
# [106]	validation_0-logloss:0.70675
# [91]	validation_0-logloss:0.69734
# [93]	validation_0-logloss:0.70232
# [91]	validation_0-logloss:0.70333
# [107]	validation_0-logloss:0.70712
# [92]	validation_0-logloss:0.69776
# [94]	validation_0-logloss:0.70278
# [92]	validation_0-logloss:0.70325
# [108]	validation_0-logloss:0.70735
# [93]	validation_0-logloss:0.69798
# [95]	validation_0-logloss:0.70320
# [93]	validation_0-logloss:0.70385
# [109]	validation_0-logloss:0.70728
# [94]	validation_0-logloss:0.69827
# [96]	validation_0-logloss:0.70378
# [94]	validation_0-logloss:0.70420
# [110]	validation_0-logloss:0.70769
# [95]	validation_0-logloss:0.69872
# [97]	validation_0-logloss:0.70396
# [95]	validation_0-logloss:0.70483
# [111]	validation_0-logloss:0.70790
# [96]	validation_0-logloss:0.69929
# [98]	validation_0-logloss:0.70419
# [96]	validation_0-logloss:0.70504
# [112]	validation_0-logloss:0.70799
# [97]	validation_0-logloss:0.69965
# [99]	validation_0-logloss:0.70418
# [97]	validation_0-logloss:0.70537
# [113]	validation_0-logloss:0.70819
# [98]	validation_0-logloss:0.69989
# [100]	validation_0-logloss:0.70457
# [98]	validation_0-logloss:0.70597
# [114]	validation_0-logloss:0.70828
# [99]	validation_0-logloss:0.70012
# [101]	validation_0-logloss:0.70466
# [99]	validation_0-logloss:0.70591
# [115]	validation_0-logloss:0.70862
# [100]	validation_0-logloss:0.70043
# [102]	validation_0-logloss:0.70494
# [100]	validation_0-logloss:0.70635
# [116]	validation_0-logloss:0.70888
# [101]	validation_0-logloss:0.70080
# [103]	validation_0-logloss:0.70498
# [101]	validation_0-logloss:0.70670
# [117]	validation_0-logloss:0.70928
# [102]	validation_0-logloss:0.70104
# [104]	validation_0-logloss:0.70518
# [102]	validation_0-logloss:0.70679
# [103]	validation_0-logloss:0.70104
# [105]	validation_0-logloss:0.70529
# [103]	validation_0-logloss:0.70700
# [104]	validation_0-logloss:0.70129
# [106]	validation_0-logloss:0.70528
# [104]	validation_0-logloss:0.70734
# [105]	validation_0-logloss:0.70144
# [107]	validation_0-logloss:0.70543
# [105]	validation_0-logloss:0.70736
# [106]	validation_0-logloss:0.70189
# [108]	validation_0-logloss:0.70551
# [106]	validation_0-logloss:0.70764
# [107]	validation_0-logloss:0.70238
# [109]	validation_0-logloss:0.70579
# [107]	validation_0-logloss:0.70787
# [108]	validation_0-logloss:0.70261
# [110]	validation_0-logloss:0.70622
# [108]	validation_0-logloss:0.70835
# [109]	validation_0-logloss:0.70282
# [111]	validation_0-logloss:0.70661
# [109]	validation_0-logloss:0.70857
# [110]	validation_0-logloss:0.70312
# [112]	validation_0-logloss:0.70688
# [110]	validation_0-logloss:0.70887
# [111]	validation_0-logloss:0.70344
# [113]	validation_0-logloss:0.70733
# [111]	validation_0-logloss:0.70910
# [112]	validation_0-logloss:0.70374
# [114]	validation_0-logloss:0.70738
# [112]	validation_0-logloss:0.70923
# [113]	validation_0-logloss:0.70397
# [115]	validation_0-logloss:0.70750
# [113]	validation_0-logloss:0.70963
# [114]	validation_0-logloss:0.70391
# [116]	validation_0-logloss:0.70777
# [114]	validation_0-logloss:0.70982
# [115]	validation_0-logloss:0.70414
# [117]	validation_0-logloss:0.70805
# [115]	validation_0-logloss:0.70997
# [116]	validation_0-logloss:0.70453
# [116]	validation_0-logloss:0.71031
# [117]	validation_0-logloss:0.70496
# [117]	validation_0-logloss:0.71024
# [118]	validation_0-logloss:0.71054
# [0]	validation_0-logloss:0.68472
# [1]	validation_0-logloss:0.67660
# [2]	validation_0-logloss:0.67005
# [3]	validation_0-logloss:0.66399
# [4]	validation_0-logloss:0.65907
# [5]	validation_0-logloss:0.65506
# [6]	validation_0-logloss:0.65165
# [7]	validation_0-logloss:0.65193
# [8]	validation_0-logloss:0.65169
# [9]	validation_0-logloss:0.64905
# [10]	validation_0-logloss:0.64772
# [11]	validation_0-logloss:0.64683
# [12]	validation_0-logloss:0.64583
# [13]	validation_0-logloss:0.64699
# [14]	validation_0-logloss:0.64639
# [15]	validation_0-logloss:0.64649
# [16]	validation_0-logloss:0.64603
# [17]	validation_0-logloss:0.64592
# [18]	validation_0-logloss:0.64621
# [19]	validation_0-logloss:0.64726
# [20]	validation_0-logloss:0.64766
# [21]	validation_0-logloss:0.64868
# [22]	validation_0-logloss:0.65072
# [23]	validation_0-logloss:0.65277
# [24]	validation_0-logloss:0.65358
# [25]	validation_0-logloss:0.65419
# [26]	validation_0-logloss:0.65546
# [27]	validation_0-logloss:0.65688
# [28]	validation_0-logloss:0.65736
# [29]	validation_0-logloss:0.65809
# [30]	validation_0-logloss:0.65905
# [31]	validation_0-logloss:0.66010
# [32]	validation_0-logloss:0.66111
# [33]	validation_0-logloss:0.66223
# [34]	validation_0-logloss:0.66303
# [35]	validation_0-logloss:0.66399
# [36]	validation_0-logloss:0.66464
# [37]	validation_0-logloss:0.66591
# [38]	validation_0-logloss:0.66717
# [39]	validation_0-logloss:0.66823
# [40]	validation_0-logloss:0.66919
# [41]	validation_0-logloss:0.67036
# [42]	validation_0-logloss:0.67157
# [43]	validation_0-logloss:0.67247
# [44]	validation_0-logloss:0.67303
# [45]	validation_0-logloss:0.67378
# [0]	validation_0-logloss:0.68480
# [46]	validation_0-logloss:0.67444
# [1]	validation_0-logloss:0.67613
# [47]	validation_0-logloss:0.67506
# [2]	validation_0-logloss:0.66923
# [48]	validation_0-logloss:0.67592
# [3]	validation_0-logloss:0.66326
# [49]	validation_0-logloss:0.67713
# [4]	validation_0-logloss:0.65801
# [50]	validation_0-logloss:0.67815
# [5]	validation_0-logloss:0.65396
# [51]	validation_0-logloss:0.67908
# [6]	validation_0-logloss:0.65055
# [52]	validation_0-logloss:0.67962
# [7]	validation_0-logloss:0.65010
# [53]	validation_0-logloss:0.68016
# [8]	validation_0-logloss:0.64968
# [54]	validation_0-logloss:0.68101
# [9]	validation_0-logloss:0.64756
# [55]	validation_0-logloss:0.68169
# [10]	validation_0-logloss:0.64602
# [56]	validation_0-logloss:0.68237
# [11]	validation_0-logloss:0.64492
# [57]	validation_0-logloss:0.68284
# [12]	validation_0-logloss:0.64358
# [58]	validation_0-logloss:0.68365
# [13]	validation_0-logloss:0.64475
# [59]	validation_0-logloss:0.68443
# [14]	validation_0-logloss:0.64407
# [60]	validation_0-logloss:0.68554
# [15]	validation_0-logloss:0.64415
# [61]	validation_0-logloss:0.68644
# [16]	validation_0-logloss:0.64373
# [62]	validation_0-logloss:0.68719
# [17]	validation_0-logloss:0.64371
# [63]	validation_0-logloss:0.68797
# [18]	validation_0-logloss:0.64381
# [64]	validation_0-logloss:0.68841
# [19]	validation_0-logloss:0.64423
# [65]	validation_0-logloss:0.68903
# [20]	validation_0-logloss:0.64455
# [66]	validation_0-logloss:0.68980
# [21]	validation_0-logloss:0.64552
# [67]	validation_0-logloss:0.69061
# [22]	validation_0-logloss:0.64739
# [68]	validation_0-logloss:0.69088
# [23]	validation_0-logloss:0.64916
# [69]	validation_0-logloss:0.69146
# [24]	validation_0-logloss:0.64995
# [70]	validation_0-logloss:0.69205
# [25]	validation_0-logloss:0.65040
# [71]	validation_0-logloss:0.69224
# [26]	validation_0-logloss:0.65192
# [72]	validation_0-logloss:0.69278
# [27]	validation_0-logloss:0.65299
# [73]	validation_0-logloss:0.69333
# [28]	validation_0-logloss:0.65385
# [74]	validation_0-logloss:0.69410
# [29]	validation_0-logloss:0.65483
# [75]	validation_0-logloss:0.69472
# [30]	validation_0-logloss:0.65598
# [76]	validation_0-logloss:0.69547
# [31]	validation_0-logloss:0.65695
# [77]	validation_0-logloss:0.69624
# [32]	validation_0-logloss:0.65822
# [78]	validation_0-logloss:0.69680
# [33]	validation_0-logloss:0.65928
# [79]	validation_0-logloss:0.69725
# [34]	validation_0-logloss:0.66023
# [80]	validation_0-logloss:0.69747
# [35]	validation_0-logloss:0.66144
# [81]	validation_0-logloss:0.69819
# [36]	validation_0-logloss:0.66238
# [82]	validation_0-logloss:0.69875
# [37]	validation_0-logloss:0.66378
# [83]	validation_0-logloss:0.69904
# [38]	validation_0-logloss:0.66486
# [84]	validation_0-logloss:0.69936
# [39]	validation_0-logloss:0.66586
# [85]	validation_0-logloss:0.69948
# [40]	validation_0-logloss:0.66684
# [86]	validation_0-logloss:0.69969
# [41]	validation_0-logloss:0.66800
# [87]	validation_0-logloss:0.70013
# [42]	validation_0-logloss:0.66886
# [88]	validation_0-logloss:0.70048
# [43]	validation_0-logloss:0.66968
# [89]	validation_0-logloss:0.70096
# [44]	validation_0-logloss:0.67091
# [90]	validation_0-logloss:0.70146
# [91]	validation_0-logloss:0.70155
# [45]	validation_0-logloss:0.67125
# [92]	validation_0-logloss:0.70189
# [46]	validation_0-logloss:0.67212
# [93]	validation_0-logloss:0.70193
# [47]	validation_0-logloss:0.67295
# [94]	validation_0-logloss:0.70233
# [48]	validation_0-logloss:0.67346
# [95]	validation_0-logloss:0.70289
# [49]	validation_0-logloss:0.67454
# [96]	validation_0-logloss:0.70335
# [50]	validation_0-logloss:0.67565
# [97]	validation_0-logloss:0.70367
# [51]	validation_0-logloss:0.67658
# [98]	validation_0-logloss:0.70411
# [52]	validation_0-logloss:0.67748
# [99]	validation_0-logloss:0.70425
# [53]	validation_0-logloss:0.67786
# [100]	validation_0-logloss:0.70457
# [54]	validation_0-logloss:0.67863
# [101]	validation_0-logloss:0.70495
# [55]	validation_0-logloss:0.67948
# [102]	validation_0-logloss:0.70529
# [56]	validation_0-logloss:0.68007
# [103]	validation_0-logloss:0.70547
# [57]	validation_0-logloss:0.68048
# [104]	validation_0-logloss:0.70569
# [58]	validation_0-logloss:0.68118
# [105]	validation_0-logloss:0.70593
# [59]	validation_0-logloss:0.68193
# [106]	validation_0-logloss:0.70621
# [60]	validation_0-logloss:0.68304
# [107]	validation_0-logloss:0.70672
# [61]	validation_0-logloss:0.68435
# [108]	validation_0-logloss:0.70711
# [62]	validation_0-logloss:0.68522
# [109]	validation_0-logloss:0.70704
# [63]	validation_0-logloss:0.68584
# [110]	validation_0-logloss:0.70742
# [64]	validation_0-logloss:0.68655
# [111]	validation_0-logloss:0.70771
# [65]	validation_0-logloss:0.68749
# [66]	validation_0-logloss:0.68826
# [67]	validation_0-logloss:0.68919
# [68]	validation_0-logloss:0.68972
# [69]	validation_0-logloss:0.69060
# [70]	validation_0-logloss:0.69117
# [71]	validation_0-logloss:0.69143
# [72]	validation_0-logloss:0.69214
# [73]	validation_0-logloss:0.69268
# [74]	validation_0-logloss:0.69338
# [75]	validation_0-logloss:0.69411
# [76]	validation_0-logloss:0.69485
# [77]	validation_0-logloss:0.69544
# [78]	validation_0-logloss:0.69568
# [79]	validation_0-logloss:0.69634
# [80]	validation_0-logloss:0.69635
# [81]	validation_0-logloss:0.69677
# [82]	validation_0-logloss:0.69740
# [83]	validation_0-logloss:0.69766
# [84]	validation_0-logloss:0.69818
# [85]	validation_0-logloss:0.69841
# [86]	validation_0-logloss:0.69867
# [87]	validation_0-logloss:0.69923
# [88]	validation_0-logloss:0.69951
# [89]	validation_0-logloss:0.69975
# [90]	validation_0-logloss:0.70005
# [91]	validation_0-logloss:0.70051
# [92]	validation_0-logloss:0.70079
# [93]	validation_0-logloss:0.70092
# [94]	validation_0-logloss:0.70143
# [95]	validation_0-logloss:0.70164
# [96]	validation_0-logloss:0.70203
# [97]	validation_0-logloss:0.70228
# [98]	validation_0-logloss:0.70264
# [99]	validation_0-logloss:0.70273
# [100]	validation_0-logloss:0.70305
# [101]	validation_0-logloss:0.70347
# [102]	validation_0-logloss:0.70377
# [103]	validation_0-logloss:0.70391
# [104]	validation_0-logloss:0.70429
# [105]	validation_0-logloss:0.70451
# [106]	validation_0-logloss:0.70446
# [107]	validation_0-logloss:0.70485
# [108]	validation_0-logloss:0.70517
# [109]	validation_0-logloss:0.70556
# [110]	validation_0-logloss:0.70609
# [111]	validation_0-logloss:0.70653
# [0]	validation_0-logloss:0.68489
# [1]	validation_0-logloss:0.67659
# [2]	validation_0-logloss:0.66994
# [3]	validation_0-logloss:0.66428
# [4]	validation_0-logloss:0.65920
# [5]	validation_0-logloss:0.65541
# [6]	validation_0-logloss:0.65218
# [7]	validation_0-logloss:0.65252
# [8]	validation_0-logloss:0.65229
# [9]	validation_0-logloss:0.64978
# [10]	validation_0-logloss:0.64813
# [11]	validation_0-logloss:0.64718
# [12]	validation_0-logloss:0.64614
# [13]	validation_0-logloss:0.64726
# [14]	validation_0-logloss:0.64642
# [15]	validation_0-logloss:0.64662
# [16]	validation_0-logloss:0.64642
# [17]	validation_0-logloss:0.64641
# [18]	validation_0-logloss:0.64642
# [19]	validation_0-logloss:0.64686
# [20]	validation_0-logloss:0.64713
# [21]	validation_0-logloss:0.64805
# [22]	validation_0-logloss:0.64989
# [23]	validation_0-logloss:0.65150
# [24]	validation_0-logloss:0.65270
# [25]	validation_0-logloss:0.65316
# [26]	validation_0-logloss:0.65437
# [27]	validation_0-logloss:0.65531
# [28]	validation_0-logloss:0.65644
# [29]	validation_0-logloss:0.65707
# [30]	validation_0-logloss:0.65810
# [31]	validation_0-logloss:0.65923
# [32]	validation_0-logloss:0.66028
# [33]	validation_0-logloss:0.66108
# [34]	validation_0-logloss:0.66175
# [35]	validation_0-logloss:0.66293
# [36]	validation_0-logloss:0.66392
# [37]	validation_0-logloss:0.66506
# [38]	validation_0-logloss:0.66649
# [39]	validation_0-logloss:0.66755
# [40]	validation_0-logloss:0.66843
# [41]	validation_0-logloss:0.66929
# [42]	validation_0-logloss:0.67016
# [43]	validation_0-logloss:0.67084
# [44]	validation_0-logloss:0.67197
# [45]	validation_0-logloss:0.67254
# [46]	validation_0-logloss:0.67341
# [47]	validation_0-logloss:0.67406
# [48]	validation_0-logloss:0.67440
# [49]	validation_0-logloss:0.67528
# [50]	validation_0-logloss:0.67642
# [51]	validation_0-logloss:0.67723
# [52]	validation_0-logloss:0.67810
# [53]	validation_0-logloss:0.67853
# [54]	validation_0-logloss:0.67945
# [55]	validation_0-logloss:0.68013
# [56]	validation_0-logloss:0.68045
# [57]	validation_0-logloss:0.68087
# [58]	validation_0-logloss:0.68142
# [59]	validation_0-logloss:0.68231
# [60]	validation_0-logloss:0.68329
# [61]	validation_0-logloss:0.68411
# [62]	validation_0-logloss:0.68501
# [63]	validation_0-logloss:0.68574
# [64]	validation_0-logloss:0.68628
# [65]	validation_0-logloss:0.68709
# [66]	validation_0-logloss:0.68803
# [67]	validation_0-logloss:0.68902
# [68]	validation_0-logloss:0.68954
# [69]	validation_0-logloss:0.69015
# [70]	validation_0-logloss:0.69094
# [71]	validation_0-logloss:0.69123
# [72]	validation_0-logloss:0.69177
# [73]	validation_0-logloss:0.69243
# [74]	validation_0-logloss:0.69332
# [75]	validation_0-logloss:0.69398
# [76]	validation_0-logloss:0.69438
# [77]	validation_0-logloss:0.69495
# [78]	validation_0-logloss:0.69541
# [79]	validation_0-logloss:0.69608
# [80]	validation_0-logloss:0.69644
# [81]	validation_0-logloss:0.69676
# [82]	validation_0-logloss:0.69725
# [83]	validation_0-logloss:0.69778
# [84]	validation_0-logloss:0.69839
# [85]	validation_0-logloss:0.69853
# [86]	validation_0-logloss:0.69889
# [87]	validation_0-logloss:0.69921
# [88]	validation_0-logloss:0.69965
# [89]	validation_0-logloss:0.70031
# [90]	validation_0-logloss:0.70074
# [91]	validation_0-logloss:0.70101
# [92]	validation_0-logloss:0.70134
# [93]	validation_0-logloss:0.70150
# [94]	validation_0-logloss:0.70170
# [95]	validation_0-logloss:0.70199
# [96]	validation_0-logloss:0.70280
# [97]	validation_0-logloss:0.70312
# [98]	validation_0-logloss:0.70366
# [99]	validation_0-logloss:0.70374
# [100]	validation_0-logloss:0.70379
# [101]	validation_0-logloss:0.70396
# [102]	validation_0-logloss:0.70430
# [103]	validation_0-logloss:0.70442
# [104]	validation_0-logloss:0.70483
# [105]	validation_0-logloss:0.70502
# [106]	validation_0-logloss:0.70523
# [107]	validation_0-logloss:0.70541
# [108]	validation_0-logloss:0.70595
# [109]	validation_0-logloss:0.70621
# [110]	validation_0-logloss:0.70651
# [111]	validation_0-logloss:0.70706
# final params {'alpha': 10, 'booster': 'gbtree', 'colsample_bylevel': 0.9, 'colsample_bytree': 0.8, 'eta': 0.05, 'gamma': 3, 'lambda': 0, 'max_depth': 9, 'n_estimators': 300, 'nthread': 4, 'objective': 'binary:logistic', 'random_state': 42, 'verbosity': 1}
# best score 0.7893077985768236

# %%
# SAVE OUTPUT
model = gcv.best_estimator_
sub = pd.read_csv("/opt/ml/input/data/sample_submission.csv")
sub["prediction"] = model.predict(test.drop("answerCode", axis=1))

output_dir = "./output/"
now = datetime.now()
now_str = "{:%Y-%m-%d_%H:%M:%S}".format(now)
file_name = f"XGB_C_grid_kfold_custom_submission_{now_str}.csv"
write_path = os.path.join(output_dir, file_name)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
with open(write_path, "w", encoding="utf8") as w:
    print("writing prediction : {}".format(write_path))
    w.write("id,prediction\n")
    for id, p in enumerate(sub["prediction"]):
        w.write("{},{}\n".format(id, p))
# Out:
# writing prediction : ./output/XGB_C_grid_kfold_custom_submission_2022-11-27_17:00:59.csv

# %%
def get_accuracy(PRED_PATH=file_name):
    threshold = 0.5
    ANSWER_PATH = "../../data/custom_answer.csv"

    submission_result = pd.read_csv(PRED_PATH)
    answer = pd.read_csv(ANSWER_PATH)

    y_pred, y = submission_result["prediction"], answer["prediction"]

    return f"accuracy_score: {accuracy_score(y,y_pred.apply(lambda x: 1 if x > threshold else 0))}\nroc  auc_score: {roc_auc_score(y,y_pred)}"

# %%
if IS_CUSTOM:
    print(get_accuracy("output/" + file_name))
# Out:
# accuracy_score: 0.603494623655914
# roc  auc_score: 0.5723758805585832

# %%
from xgboost import plot_importance

plot_importance(model)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
ft_importance_values = model.feature_importances_

# 정렬과 시각화를 쉽게 하기 위해 series 전환
ft_series = pd.Series(ft_importance_values, index=x_train.columns)
ft_top20 = ft_series.sort_values(ascending=False)[:20]

# 시각화
plt.figure(figsize=(8, 6))
plt.title("Feature Importance Top 20")
sns.barplot(x=ft_top20, y=ft_top20.index)
plt.show()
